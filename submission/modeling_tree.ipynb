# %% [markdown]
# # Tree Based Models
# This notebook include models on:
# * Decision trees with DecisionTreeRegressor
# * Random Forest with RandomForestRegressor
# * XG Boosting with xgb

# %% [markdown]
# ## Import Libraries

# %%
# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# General libraries.
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
from numpy import arange
import seaborn as sns
import plotly.express as px
import time

# SK-learn libraries for processing.
from sklearn import preprocessing
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn import set_config

# SK-learn libraries for learning.
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeRegressor 
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb

# SK-learn libraries for evaluation.
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score

pd.options.display.max_rows = 4000

# %% [markdown]
# ## Import Data
# Data imported is the final NBA data that include past NBA games since 2005 joined with each team's player clusters

# %%
nba_data_final = pd.read_csv('nba_final_data.csv')

# %% [markdown]
# Check the outcome variable on margin of victory

# %%
nba_data_final['PLUS_MINUS_HOME'].describe()
# Out:
# count    16635.000000
# mean         2.897205
# std         13.312930
# min        -56.000000
# 25%         -7.000000
# 50%          4.000000
# 75%         11.000000
# max         61.000000
# Name: PLUS_MINUS_HOME, dtype: float64

# %%
nba_data_final.head()
# Out:
#     GAME_ID  TEAM_ID_HOME  TEAM_ID_AWAY   GAME_DATE  SEASON  PLUS_MINUS_HOME  \
# 0  20400946    1610612737    1610612764  2005-03-16    2004              -29
# 1  20500068    1610612737    1610612746  2005-11-10    2005               -7
# 2  20500082    1610612737    1610612763  2005-11-12    2005               -1
# 3  20500156    1610612737    1610612738  2005-11-23    2005                3
# 4  20500190    1610612737    1610612757  2005-11-27    2005               -2
#
#    MIN_HOME   FGA_HOME  FG_PCT_HOME  FG3A_HOME  ...  cluster_2a  cluster_3a  \
# 0     240.0  82.000000     0.439000  14.000000  ...           2           0
# 1     240.0  78.500000     0.466000  14.500000  ...           1           0
# 2     240.0  82.666667     0.446333  12.666667  ...           1           0
# 3     240.0  82.750000     0.434250  12.500000  ...           2           0
# 4     240.0  80.600000     0.458600  11.600000  ...           0           0
#
#    cluster_4a  cluster_5a  cluster_6a  cluster_7a  cluster_8a  cluster_9a  \
# 0           1           2           0           0           0           3
# 1           0           1           1           0           1           6
# 2           0           2           1           0           0           5
# 3           0           1           0           0           1           6
# 4           2           2           2           0           1           5
#
#    cluster_10a  cluster_11a
# 0            0            2
# 1            0            1
# 2            0            0
# 3            1            1
# 4            0            0
#
# [5 rows x 71 columns]

# %%
nba_data_final.shape
# Out:
# (16635, 71)

# %% [markdown]
# **Drop columns that are not used in the model**

# %%
game_data = nba_data_final.drop(['GAME_ID','TEAM_ID_HOME','TEAM_ID_AWAY','GAME_DATE','SEASON'
                                          # , 'MIN_HOME','FGA_HOME','FGA_AWAY','STL_AWAY','STL_HOME','PF_AWAY','PF_HOME',
                                          #  'FG_PCT_AWAY','FG_PCT_HOME','FG3A_AWAY','FG3A_HOME'                                            
                                           ], axis = 1)

# %%
game_data.head()
# Out:
#    PLUS_MINUS_HOME  MIN_HOME   FGA_HOME  FG_PCT_HOME  FG3A_HOME  FG3_PCT_HOME  \
# 0              -29     240.0  82.000000     0.439000  14.000000      0.571000
# 1               -7     240.0  78.500000     0.466000  14.500000      0.419000
# 2               -1     240.0  82.666667     0.446333  12.666667      0.316333
# 3                3     240.0  82.750000     0.434250  12.500000      0.320500
# 4               -2     240.0  80.600000     0.458600  11.600000      0.406400
#
#     FTA_HOME  FT_PCT_HOME  OREB_HOME  DREB_HOME  ...  cluster_2a  cluster_3a  \
# 0  17.000000     0.765000  15.000000       25.0  ...           2           0
# 1  21.500000     0.748000  12.000000       28.0  ...           1           0
# 2  23.333333     0.745667  13.666667       27.0  ...           1           0
# 3  22.250000     0.743500  14.250000       27.5  ...           2           0
# 4  25.400000     0.773800  14.200000       26.8  ...           0           0
#
#    cluster_4a  cluster_5a  cluster_6a  cluster_7a  cluster_8a  cluster_9a  \
# 0           1           2           0           0           0           3
# 1           0           1           1           0           1           6
# 2           0           2           1           0           0           5
# 3           0           1           0           0           1           6
# 4           2           2           2           0           1           5
#
#    cluster_10a  cluster_11a
# 0            0            2
# 1            0            1
# 2            0            0
# 3            1            1
# 4            0            0
#
# [5 rows x 66 columns]

# %% [markdown]
# ## Define features and out comes and split data

# %% [markdown]
# Define features (game_data_x) and outcome (game_data_y)

# %%
game_data_x = game_data.drop(['PLUS_MINUS_HOME','WL_Home_modified'], axis = 1)
game_data_y = game_data['PLUS_MINUS_HOME']

# %% [markdown]
# Split to training and testing at 80/20 proportion

# %%
X_train, X_test, y_train, y_test = train_test_split(game_data_x, 
                                                    game_data_y, 
                                                    test_size=0.2, random_state=42)

# %% [markdown]
# Created normalized and standardized training and testing

# %%
X_train_normalized = preprocessing.normalize(X_train)
X_train_standardized = standardized_X = preprocessing.scale(X_train)
X_test_normalized = preprocessing.normalize(X_test)
X_test_standardized = standardized_X = preprocessing.scale(X_test)

# %% [markdown]
# ## Define evaluation method
# Calculate evaluation metrics based on the predict outcome and actual outcome for:
# * Accuracy
# * F1 Score
# * R square
# * RMSE

# %%
def model_evaluation(y_pred, y_actual):
    """
    returns evaluation metrics for the model:
    Accuracy, F1 Score, R Squre, RMSE
    """
    acc = 0
    f1score = 0
    rmse = 0
    r_sqaure = 0
    
    if len(y_pred) != len(y_actual):
        print('predicted and actual length not equal')
        
    else:
        len_y = len(y_pred)
        
        y_pred_bool =  y_pred >= 0
        y_actual_bool =  y_actual >= 0
        f1score = f1_score(y_actual_bool, y_pred_bool, average='binary')
        acc = accuracy_score(y_actual_bool, y_pred_bool)
        
        rmse = np.sqrt(mse(y_actual, y_pred))
        r_sqaure = r2_score(y_actual, y_pred)
        
    df_evaluation = pd.DataFrame({'Accuracy': pd.Series(acc),
                                 'F1 Score': pd.Series(f1score),
                                 'R Square': pd.Series(r_sqaure),
                                 'RMSE': pd.Series(rmse)})
    return(df_evaluation)

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# Decision Tree Regressor on training and testing without normalization nor standardization

# %%
regressor = DecisionTreeRegressor(random_state = 0,
                                  criterion='mse', max_depth=50,
                                  max_leaf_nodes=30,
                                  min_samples_leaf=100, min_samples_split=100) 
regressor.fit(X_train, y_train)

y_pred_train = regressor.predict(X_train)
y_pred_test = regressor.predict(X_test)

print ("Evaluation metrics on training data: ")
print(model_evaluation(y_pred_train, y_train))
print('\n')
print ("Evaluation metrics on testing data: ")
print(model_evaluation(y_pred_test, y_test))
print('\n')

#plt.scatter(y_train,y_pred_train)
#plt.scatter(y_test,y_pred_test)

feat_importances = pd.Series(regressor.feature_importances_, index=X_train.columns)
feat_importances.nlargest(10).plot(kind='barh')

plt.xlabel('Importance of the features')
plt.ylabel('features')
plt.title('Feature Importance')
plt.show()
# Out:
# Evaluation metrics on training data:
#    Accuracy  F1 Score  R Square     RMSE
# 0  0.632627  0.736029  0.093848  12.6463
#
#
# Evaluation metrics on testing data:
#    Accuracy  F1 Score  R Square       RMSE
# 0  0.625789  0.732546  0.063731  12.982533

# %% [markdown]
# Decision Tree Regressor on normalized training and testing

# %%
regressor_normalized = DecisionTreeRegressor(random_state = 0,
                                             criterion='mse', max_depth=50,
                                             max_leaf_nodes=30,
                                             min_samples_leaf=100, min_samples_split=100) 
regressor_normalized.fit(X_train_normalized, y_train)

y_pred_train_normalized = regressor_normalized.predict(X_train_normalized)
y_pred_test_normalized = regressor_normalized.predict(X_test_normalized)

print ("Evaluation metrics on training data: ")
print(model_evaluation(y_pred_train_normalized, y_train))
print('\n')
print ("Evaluation metrics on testing data: ")
print(model_evaluation(y_pred_test_normalized, y_test))
print('\n')
#plt.scatter(y_train,y_pred_train)
#plt.scatter(y_test,y_pred_test)

feat_importances_normalized = pd.Series(regressor_normalized.feature_importances_, index=X_train.columns)
feat_importances_normalized.nlargest(10).plot(kind='barh')

plt.xlabel('Importance of the features')
plt.ylabel('features')
plt.title('Feature Importance')
plt.show()
# Out:
# Evaluation metrics on training data:
#    Accuracy  F1 Score  R Square       RMSE
# 0  0.637211  0.740067  0.099394  12.607536
#
#
# Evaluation metrics on testing data:
#    Accuracy  F1 Score  R Square       RMSE
# 0  0.628795  0.737066  0.054845  13.043994

# %% [markdown]
# Decision Tree Regressor on standardized training and testing

# %%
regressor_standardized = DecisionTreeRegressor(random_state = 0,
                                               criterion='mse', max_depth=50,
                                               max_leaf_nodes=30,
                                               min_samples_leaf=100, min_samples_split=100) 
regressor_standardized.fit(X_train_standardized, y_train)

y_pred_train_standardized = regressor_standardized.predict(X_train_standardized)
y_pred_test_standardized = regressor_standardized.predict(X_test_standardized)

print ("Evaluation metrics on training data: ")
print(model_evaluation(y_pred_train_standardized, y_train))
print('\n')
print ("Evaluation metrics on testing data: ")
print(model_evaluation(y_pred_test_standardized, y_test))
print('\n')

#plt.scatter(y_train,y_pred_train)
#plt.scatter(y_test,y_pred_test)

feat_importances_normalized = pd.Series(regressor_standardized.feature_importances_, index=X_train.columns)
feat_importances_normalized.nlargest(10).plot(kind='barh')

plt.xlabel('Importance of the features')
plt.ylabel('features')
plt.title('Feature Importance')
plt.show()
# Out:
# Evaluation metrics on training data:
#    Accuracy  F1 Score  R Square     RMSE
# 0  0.632627  0.736029  0.093848  12.6463
#
#
# Evaluation metrics on testing data:
#    Accuracy  F1 Score  R Square      RMSE
# 0  0.626991  0.733976  0.064938  12.97416

# %% [markdown]
# **Since standardized performed better than normalized, the models below are based on standarized training and testing datasets**

# %% [markdown]
# ### Parameter tunning for decision tree regression

# %% [markdown]
# Define the parameters for tunning

# %%
# Other paramter with wider range are tunned and the range was narrowed to get to the one below that gives the best result
parameters_decision_tree={"splitter":["best","random"],
                          "max_depth" : [5,10,20,30],
                          "min_samples_leaf":[10,20,30,40],
                          "min_weight_fraction_leaf":[0.01,0.1],
                          "max_features":["auto","log2","sqrt",None],
                          "max_leaf_nodes":[None,40, 80, 120] }

# %% [markdown]
# Tune model

# %%
reg_decision_model_stand=DecisionTreeRegressor()

tuning_model_decision_tree_stand=GridSearchCV(reg_decision_model_stand,
                                              param_grid=parameters_decision_tree,
                                              scoring='neg_mean_squared_error',
                                              cv=3,
                                              verbose=3)

start_time_train = time.time()

tuned_mode_stand = tuning_model_decision_tree_stand.fit(X_train_standardized,y_train)

end_time_train = time.time()
time_used = end_time_train - start_time_train
print("Time used to tune  the model:"  + str(time_used))
# Out:
# Fitting 3 folds for each of 1024 candidates, totalling 3072 fits
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.2s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-163.251, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-171.997, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-169.837, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-166.208, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-173.037, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-172.535, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.2s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.2s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-164.219, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-172.312, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-169.965, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-169.128, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-174.345, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-171.572, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.2s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.2s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-164.995, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-171.488, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-168.515, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-167.757, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-175.307, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-171.827, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.2s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-164.091, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-172.147, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-168.102, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-168.307, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-174.312, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-169.855, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.2s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.2s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-163.980, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-171.520, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-171.030, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-167.499, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-176.336, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-171.568, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-161.860, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-172.404, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-169.404, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-166.995, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-174.284, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-175.052, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-164.406, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-171.544, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-168.851, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-164.535, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-172.641, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-171.525, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-164.162, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-171.397, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-172.910, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-163.309, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-174.205, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-172.223, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-165.712, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-172.109, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-170.276, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-168.411, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-175.535, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-169.890, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-163.955, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-171.814, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-169.815, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-166.673, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-173.467, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-174.281, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.2s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.2s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-162.496, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-171.787, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-171.338, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-166.588, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-176.211, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-170.507, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-164.301, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-173.538, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-166.816, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-166.629, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-175.281, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-171.936, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-164.720, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-170.504, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-169.724, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-167.570, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-174.633, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-170.458, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-168.943, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-166.163, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-171.450, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-170.218, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-164.629, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-177.512, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-173.821, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-165.533, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-171.245, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# ...
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-171.437, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-170.555, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-164.776, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-175.128, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-170.753, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-168.256, total=   0.2s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-172.945, total=   0.2s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-174.602, total=   0.2s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-167.203, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-169.851, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-169.228, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-166.261, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-174.577, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-172.463, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-168.256, total=   0.2s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-172.943, total=   0.2s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-174.602, total=   0.2s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-163.907, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-170.446, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-168.458, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-167.294, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-174.329, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-169.843, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-168.256, total=   0.2s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-172.945, total=   0.2s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-174.602, total=   0.2s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-165.422, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-170.155, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-170.878, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-165.797, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-172.220, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-171.666, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-168.256, total=   0.2s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-172.943, total=   0.2s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-174.602, total=   0.2s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-164.971, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-170.654, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-167.141, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-165.569, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-171.867, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-171.527, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-166.052, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-174.286, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-172.053, total=   0.0s
# Time used to tune  the model:160.32665348052979
# [Parallel(n_jobs=1)]: Done 3072 out of 3072 | elapsed:  2.7min finished

# %% [markdown]
# Get the best parameters

# %%
tuned_mode_stand.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': 'auto',
#  'max_leaf_nodes': 80,
#  'min_samples_leaf': 20,
#  'min_weight_fraction_leaf': 0.01,
#  'splitter': 'random'}

# %%
tuned_mode_stand.best_estimator_
# Out:
# DecisionTreeRegressor(max_depth=10, max_features='auto', max_leaf_nodes=80,
#                       min_samples_leaf=20, min_weight_fraction_leaf=0.01,
#                       splitter='random')

# %% [markdown]
# Run the DecisionTreeRegressor with the best parameters based on parameter tunning

# %%
regressor_tuned = DecisionTreeRegressor(max_depth=10, max_features='auto', max_leaf_nodes=80,
                                        min_samples_leaf=20, min_weight_fraction_leaf=0.01,
                                        splitter='random', criterion='mse') 
regressor_tuned.fit(X_train_standardized, y_train)

y_pred_train_tuned = regressor_tuned.predict(X_train_standardized)
y_pred_test_tuned = regressor_tuned.predict(X_test_standardized)

print ("Evaluation metrics on training data: ")
print(model_evaluation(y_pred_train_tuned, y_train))
print('\n')
print ("Evaluation metrics on testing data: ")
print(model_evaluation(y_pred_test_tuned, y_test))
print('\n')

#plt.scatter(y_train,y_pred_train_tuned)
#plt.scatter(y_test,y_pred_test_tuned)

feat_importances_tuned = pd.Series(regressor_tuned.feature_importances_, index=X_train.columns)
feat_importances_tuned.nlargest(10).plot(kind='barh')

plt.xlabel('Importance of the features')
plt.ylabel('features')
plt.title('Feature Importance')
plt.show()
# Out:
# Evaluation metrics on training data:
#    Accuracy  F1 Score  R Square       RMSE
# 0  0.631425  0.729379  0.090377  12.670495
#
#
# Evaluation metrics on testing data:
#    Accuracy  F1 Score  R Square       RMSE
# 0  0.634806  0.736271  0.061603  12.997274

# %% [markdown]
# **The tuned decision tree regressor was not performing better, but the training dataset use less overfitting.**

# %% [markdown]
# ## Random Forest

# %% [markdown]
# **Train with a basic random forest regressor**

# %%
set_config(print_changed_only=False) 
 
rfr_standardized = RandomForestRegressor()
rfr_standardized.fit(X_train_standardized, y_train)

y_pred_rfr_train_standardized = rfr_standardized.predict(X_train_standardized)

y_pred_rfr_test_standardized = rfr_standardized.predict(X_test_standardized)

print ("Evaluation metrics on training data: ")
print(model_evaluation(y_pred_rfr_train_standardized, y_train))
print('\n')
print ("Evaluation metrics on testing data: ")
print(model_evaluation(y_pred_rfr_test_standardized, y_test))
print('\n')
# Out:
# Evaluation metrics on training data:
#    Accuracy  F1 Score  R Square      RMSE
# 0  0.948452  0.957312  0.870941  4.772615
#
#
# Evaluation metrics on testing data:
#    Accuracy  F1 Score  R Square       RMSE
# 0  0.633904  0.722045  0.078068  12.882742

# %%
plt.xlabel('Predicted outcome vs actual outcome for training data')
plt.ylabel('Predicted Outcome')
plt.title('Feature Actual Outcome')
plt.scatter(y_train,y_pred_rfr_train_standardized)

# %%
plt.xlabel('Predicted outcome vs actual outcome for testing data')
plt.ylabel('Predicted Outcome')
plt.title('Feature Actual Outcome')
plt.scatter(y_test,y_pred_rfr_test_standardized)

# %% [markdown]
# ### Parameter tunning for random forest regressor

# %%
# Other paramter with wider range are tunned and the range was narrowed to get to the one below that gives the best result

param_grid = {
    'bootstrap': [True],
    'max_depth': [70, 72, 74],
    'max_features': [20, 30, 40],
    'min_samples_leaf': [10, 14, 18],
    'min_samples_split': [13, 14, 15],
    'n_estimators': [2200, 2400, 2600]
}

rf = RandomForestRegressor()

grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

# %%
rf_tuned = grid_search.fit(X_train_standardized, y_train)
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed: 111.0min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed: 293.4min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed: 533.8min
# [Parallel(n_jobs=-1)]: Done 729 out of 729 | elapsed: 635.9min finished

# %%
rf_tuned.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 70,
#  'max_features': 20,
#  'min_samples_leaf': 18,
#  'min_samples_split': 14,
#  'n_estimators': 2400}

# %%
best_grid = rf_tuned.best_estimator_
best_grid
# Out:
# RandomForestRegressor(max_depth=70, max_features=20, min_samples_leaf=18,
#                       min_samples_split=14, n_estimators=2400)

# %% [markdown]
# Run the DecisionTreeRegressor with the best parameters based on parameter tunning

# %%
rf_tuned = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=70, max_features=20, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=18,
                      min_samples_split=14, min_weight_fraction_leaf=0.0,
                      n_estimators=2400, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False) 
rf_tuned.fit(X_train_standardized, y_train)

y_pred_rf_train_tuned = rf_tuned.predict(X_train_standardized)
y_pred_rf_test_tuned = rf_tuned.predict(X_test_standardized)

feat_importances_rf_tuned = pd.Series(rf_tuned.feature_importances_, index=X_train.columns)
feat_importances_rf_tuned.nlargest(10).plot(kind='barh')

plt.xlabel('Importance of the features')
plt.ylabel('features')
plt.title('Feature Importance')
plt.show()

print ("Evaluation metrics on training data: ")
print(model_evaluation(y_pred_rf_train_tuned, y_train))
print('\n')
print ("Evaluation metrics on testing data: ")
print(model_evaluation(y_pred_rf_test_tuned, y_test))
print('\n')
# Out:
# Evaluation metrics on training data:
#    Accuracy  F1 Score  R Square       RMSE
# 0  0.752931  0.813033   0.35238  10.691114
#
#
# Evaluation metrics on testing data:
#    Accuracy  F1 Score  R Square       RMSE
# 0  0.645927  0.741213  0.109036  12.664531

# %%
plt.xlabel('Predicted outcome vs actual outcome for training data')
plt.ylabel('Predicted Outcome')
plt.title('Feature Actual Outcome')
plt.scatter(y_train,y_pred_rf_train_tuned)

# %%
plt.xlabel('Predicted outcome vs actual outcome for testing data')
plt.ylabel('Predicted Outcome')
plt.title('Feature Actual Outcome')
plt.scatter(y_test,y_pred_rf_test_tuned)

# %% [markdown]
# ## XG Boosting

# %% [markdown]
# Run a basic XGB regressor

# %%
model = xgb.XGBRegressor()

model.fit(X_train_normalized, y_train)
y_pred_model= model.predict(X_train_normalized)
y_pred_model_test = model.predict(X_test_normalized)

print ("Evaluation metrics on training data: ")
print(model_evaluation(y_pred_model, y_train))
print('\n')
print ("Evaluation metrics on testing data: ")
print(model_evaluation(y_pred_model_test, y_test))
print('\n')

feat_importances_rf_tuned = pd.Series(rf_tuned.feature_importances_, index=X_train.columns)
feat_importances_rf_tuned.nlargest(10).plot(kind='barh')

plt.xlabel('Importance of the features')
plt.ylabel('features')
plt.title('Feature Importance')
plt.show()

# %% [markdown]
# ### Parameter tunning for random forest regressor

# %%
# Other paramter with wider range are tunned and the range was narrowed to get to the one below that gives the best result

param_tuning = {
        'learning_rate': [0.01,0.05],
        'max_depth': [5, 7,9],
        'min_child_weight': [ 5,9,13],
        'subsample': [ 0.7,0.9],
        'colsample_bytree': [0.7, 0.9],
        'n_estimators' : [900,1200,1500],
        'objective': ['reg:squarederror']
    }

# %%
xgb_model = xgb.XGBRegressor()

gsearch = GridSearchCV(estimator = xgb_model,
                           param_grid = param_tuning,                        
                           scoring = 'neg_mean_squared_error',
                           cv = 3,
                           n_jobs = -1,
                           verbose = 1)

# %%
xgb_tuning = gsearch.fit(X_train_standardized,y_train)
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed: 48.5min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed: 126.6min
# [Parallel(n_jobs=-1)]: Done 648 out of 648 | elapsed: 225.8min finished

# %%
xgb_tuning.best_params_
# Out:
# {'colsample_bytree': 0.9,
#  'learning_rate': 0.01,
#  'max_depth': 5,
#  'min_child_weight': 9,
#  'n_estimators': 900,
#  'objective': 'reg:squarederror',
#  'subsample': 0.9}

# %%
best_grid_xgb = xgb_tuning.best_estimator_
best_grid_xgb
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.9, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.01, max_delta_step=0,
#              max_depth=5, min_child_weight=9, missing=nan,
#              monotone_constraints='()', n_estimators=900, n_jobs=8,
#              num_parallel_tree=1, objective='reg:squarederror',
#              predictor='auto', random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=0.9, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
xgb_tuned = xgb.XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=0.9, enable_categorical=False,
             gamma=0, gpu_id=-1, importance_type=None,
             interaction_constraints='', learning_rate=0.01, max_delta_step=0,
             max_depth=5, min_child_weight=9,
             monotone_constraints='()', n_estimators=700, n_jobs=8,
             num_parallel_tree=1, objective='reg:squarederror',
             predictor='auto', random_state=0, reg_alpha=0, reg_lambda=1,
             scale_pos_weight=1, subsample=0.9, tree_method='exact',
             validate_parameters=1, verbosity=None)
xgb_tuned.fit(X_train_standardized, y_train)

y_pred_xgb_train_tuned = xgb_tuned.predict(X_train_standardized)
y_pred_xgb_test_tuned = xgb_tuned.predict(X_test_standardized)

feat_importances_tuned = pd.Series(xgb_tuned.feature_importances_, index=X_train.columns)
feat_importances_tuned.nlargest(10).plot(kind='barh')

plt.xlabel('Importance of the features')
plt.ylabel('features')
plt.title('Feature Importance')
plt.show()

print ("Evaluation metrics on training data: ")
print(model_evaluation(y_pred_xgb_train_tuned, y_train))
print('\n')
print ("Evaluation metrics on testing data: ")
print(model_evaluation(y_pred_xgb_test_tuned, y_test))
print('\n')
# Out:
# Evaluation metrics on training data:
#    Accuracy  F1 Score  R Square       RMSE
# 0  0.717388  0.785098   0.29884  11.124265
#
#
# Evaluation metrics on testing data:
#    Accuracy  F1 Score  R Square       RMSE
# 0  0.659152  0.745854  0.133189  12.491686

# %% [markdown]
# ## PCA
# Check whether PCA improve the model performance
# Since PCA did not improve the model performance, training with PCA is not persued further

# %%
pca = PCA().fit(X_train_standardized)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.title('Variance explained by PCA');

# %%
pca = PCA(n_components=30)
game_without_outcome_pca_train = pca.fit_transform(X_train_standardized)
game_without_outcome_pca_test = pca.fit_transform(X_test_standardized)

# %%
regressor_tuned_pca = DecisionTreeRegressor(max_depth=10, max_features='auto', max_leaf_nodes=80,
                                        min_samples_leaf=20, min_weight_fraction_leaf=0.01,
                                        splitter='random', criterion='mse') 
regressor_tuned_pca.fit(game_without_outcome_pca_train, y_train)

y_pred_train_tuned_pca = regressor_tuned_pca.predict(game_without_outcome_pca_train)
y_pred_test_tuned_pca = regressor_tuned_pca.predict(game_without_outcome_pca_test)

feat_importances_tuned_pca = pd.Series(regressor_tuned_pca.feature_importances_)
feat_importances_tuned_pca.nlargest(10).plot(kind='barh')
plt.xlabel('Importance of the features')
plt.ylabel('features')
plt.title('Feature Importance')
plt.show()

print ("Evaluation metrics on training data: ")
print(model_evaluation(y_pred_train_tuned_pca, y_train))
print('\n')
print ("Evaluation metrics on testing data: ")
print(model_evaluation(y_pred_test_tuned_pca, y_test))
print('\n')
# Out:
# Evaluation metrics on training data:
#    Accuracy  F1 Score  R Square       RMSE
# 0  0.617448  0.727739  0.062153  12.865568
#
#
# Evaluation metrics on testing data:
#    Accuracy  F1 Score  R Square       RMSE
# 0  0.567779  0.699037 -0.081725  13.954601

# %%
reg_decision_model_pca=DecisionTreeRegressor()

tuning_model_decision_tree_pca=GridSearchCV(reg_decision_model_pca,
                                        param_grid=parameters_decision_tree,
                                        scoring='neg_mean_squared_error',
                                        cv=3,
                                        verbose=3)

# %%
tuned_model_pca = tuning_model_decision_tree_pca.fit(game_without_outcome_pca_train,y_train)
# Out:
# Fitting 3 folds for each of 1024 candidates, totalling 3072 fits
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-166.644, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-171.839, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-169.267, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-169.437, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-175.867, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-170.745, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-167.433, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-169.934, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-172.649, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-167.367, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-176.243, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-176.493, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-166.052, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-173.724, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-170.802, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-167.022, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-173.196, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-175.739, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-165.475, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-172.171, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-172.143, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-167.784, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-176.683, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=None, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-169.731, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-166.576, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-172.463, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-171.629, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-168.252, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-172.563, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-173.697, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-167.718, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-171.789, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-169.862, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-168.216, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-175.867, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-173.617, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-166.366, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-173.479, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-170.562, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-167.575, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-177.239, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-173.336, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-166.811, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-171.769, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-170.589, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-168.450, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-178.345, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=40, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-172.320, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-165.244, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-171.066, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-171.646, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-169.886, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-177.435, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-175.415, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-167.901, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-172.109, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-172.114, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-171.238, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-177.156, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-171.406, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-166.808, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-171.913, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-171.587, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-170.558, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-177.562, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-173.203, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-166.197, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-171.158, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-172.495, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-166.809, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-173.865, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-176.058, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-166.929, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-170.367, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-171.872, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-170.251, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-175.110, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-172.849, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-172.502, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-166.969, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-171.072, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-170.339, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-169.847, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-178.076, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-173.619, total=   0.0s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-166.234, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-169.281, total=   0.1s
# [CV] max_depth=5, max_features=auto, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# ...
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-171.831, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-170.753, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-167.231, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-178.105, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=80, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-173.118, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-171.293, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-174.527, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=best, score=-176.538, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-167.096, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-169.651, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.01, splitter=random, score=-169.866, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-168.390, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-179.812, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random, score=-171.107, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-171.293, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-174.527, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=best, score=-176.538, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-165.427, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-169.578, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.01, splitter=random, score=-169.877, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-170.294, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-178.811, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=20, min_weight_fraction_leaf=0.1, splitter=random, score=-171.604, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-171.293, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-174.527, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=best, score=-176.538, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-165.849, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-170.666, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.01, splitter=random, score=-172.132, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-169.369, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-176.354, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=30, min_weight_fraction_leaf=0.1, splitter=random, score=-175.363, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-171.293, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-174.527, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=best, score=-176.538, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-164.332, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-170.428, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.01, splitter=random, score=-170.320, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-166.104, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-169.929, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=best, score=-170.142, total=   0.1s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-168.368, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-178.286, total=   0.0s
# [CV] max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random
# [CV]  max_depth=30, max_features=None, max_leaf_nodes=120, min_samples_leaf=40, min_weight_fraction_leaf=0.1, splitter=random, score=-173.362, total=   0.0s
# [Parallel(n_jobs=1)]: Done 3072 out of 3072 | elapsed:  2.1min finished

# %%
best_grid = tuned_model_pca.best_estimator_
best_grid
# Out:
# DecisionTreeRegressor(max_depth=20, min_samples_leaf=40,
#                       min_weight_fraction_leaf=0.01, splitter='random')

# %%
regressor_tuned_pca = DecisionTreeRegressor(max_depth=20, min_samples_leaf=40,
                                            min_weight_fraction_leaf=0.01, splitter='random', 
                                            criterion='mse') 
regressor_tuned_pca.fit(game_without_outcome_pca_train, y_train)

y_pred_train_tuned_pca = regressor_tuned_pca.predict(game_without_outcome_pca_train)
y_pred_test_tuned_pca = regressor_tuned_pca.predict(game_without_outcome_pca_test)

feat_importances_tuned_pca = pd.Series(regressor_tuned_pca.feature_importances_)
feat_importances_tuned_pca.nlargest(10).plot(kind='barh')
plt.xlabel('Importance of the features')
plt.ylabel('features')
plt.title('Feature Importance')
plt.show()

print ("Evaluation metrics on training data: ")
print(model_evaluation(y_pred_train_tuned_pca, y_train))
print('\n')
print ("Evaluation metrics on testing data: ")
print(model_evaluation(y_pred_test_tuned_pca, y_test))
print('\n')
# Out:
# Evaluation metrics on training data:
#    Accuracy  F1 Score  R Square       RMSE
# 0  0.619853  0.721742  0.068454  12.822276
#
#
# Evaluation metrics on testing data:
#    Accuracy  F1 Score  R Square       RMSE
# 0   0.54193  0.671835 -0.119985  14.199237
